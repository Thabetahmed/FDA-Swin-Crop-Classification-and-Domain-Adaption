# %%
import geopandas as gpd
mosta_data = gpd.read_file('potato/Classes_PDT2021.shp')
print(mosta_data)
# Out:
#    OBJECTID  Shape_Leng    Shape_Area             classes  \
# 0         1  62476.2456  2.880076e+06  Non pomme de terre
# 1         2  52921.3684  1.789716e+06      Pomme de terre
#
#                                             geometry
# 0  MULTIPOLYGON (((790903.527 3959363.844, 790903...
# 1  MULTIPOLYGON (((793708.068 3964050.71, 793708....
